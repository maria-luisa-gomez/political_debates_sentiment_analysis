# %% [markdown]
# # Get and Post API requests

# %%
# Libraries

import requests
import pandas as pd
import sys, json
import os
import dotenv
import sqlalchemy as alch
# import urllib.parse
from dotenv import load_dotenv

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
# passw_env = os.getenv("pass_sql")

# %%
dbName = "political_debates"

# %%
# passw = os.getenv("passw_env")
passw = "admin"
dbName="political_debates"
connectionData=f"mysql+pymysql://root:{passw}@localhost/{dbName}"
engine = alch.create_engine(connectionData)

# %% [markdown]
# ## GET REQUESTS

# %% [markdown]
# #### Query by speaker

# %%
speaker = "Donald Trump"

# %%
url = f"http://127.0.0.1:5000/sentences/{speaker}"

# %%
variable = requests.get(url)

# %%
variable.json()[:2]
# Out:
# [{'sentenceid': 3,
#   'minute': 10140000,
#   'sentence': 'How you doing man',
#   'speakers_speakerid': 2,
#   'debate': 'us_election_2020_1st_presidential_debate',
#   'speakerid': 2,
#   'speaker': 'Donald Trump'},
#  {'sentenceid': 5,
#   'minute': 10260000,
#   'sentence': 'Im well',
#   'speakers_speakerid': 2,
#   'debate': 'us_election_2020_1st_presidential_debate',
#   'speakerid': 2,
#   'speaker': 'Donald Trump'}]

# %% [markdown]
# ## POST REQUESTS

# %%
register = {
    "speaker": "Donald Trump",
    "minute": "01:10",
    "sentence": "I use peanut butter to do my fake tan",
    "debate": "us_election_2020_1st_presidential_debate"
}

# %%
register_2 = {
    "speaker": "Donald Trump", 
    "minute": "01:10", 
    "sentence": "I drink a lot of coke",  
    "debate": "us_election_2020_1st_presidential_debate"
}

# %%
url2 = f"http://127.0.0.1:5000/newsentence"

# %%
variable2 = requests.post(url2, data=complete_register2)

# %%
variable2.json()

# %%
type(variable2)
